# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json("../data/exercises.json")
df.shape
# Out:
# (873, 11)

# %%
df.loc[df['mechanic'].isnull()]
# Out:
#                          name   force         level mechanic  equipment  \
# 1             90/90 Hamstring    push      beginner     None  body only
# 5              Adductor/Groin  static  intermediate     None       None
# 8      All Fours Quad Stretch  static  intermediate     None  body only
# 21          Ankle On The Knee  static      beginner     None       None
# 22      Anterior Tibialis-SMR  static  intermediate     None      other
# ..                        ...     ...           ...      ...        ...
# 836        Upper Back Stretch  static      beginner     None       None
# 840            Upward Stretch  static      beginner     None       None
# 844        Walking, Treadmill    None      beginner     None    machine
# 864                 Windmills    pull  intermediate     None       None
# 865  World's Greatest Stretch  static  intermediate     None       None
#
#     primaryMuscles                  secondaryMuscles  \
# 1     [hamstrings]                          [calves]
# 5      [adductors]                                []
# 8     [quadriceps]                      [quadriceps]
# 21        [glutes]                                []
# 22        [calves]                                []
# ..             ...                               ...
# 836  [middle back]                     [middle back]
# 840    [shoulders]                     [chest, lats]
# 844   [quadriceps]      [calves, glutes, hamstrings]
# 864    [abductors]  [glutes, hamstrings, lower back]
# 865   [hamstrings]      [calves, glutes, quadriceps]
#
#                                           instructions    category  \
# 1    [Lie on your back, with one leg extended strai...  stretching
# 5    [Lie on your back with your feet raised toward...  stretching
# 8    [Start off on your hands and knees, then lift ...  stretching
# 21   [From a lying position, bend your knees and ke...  stretching
# 22   [Begin seated on the ground with your legs ben...  stretching
# ..                                                 ...         ...
# 836  [Clasp fingers together with your thumbs point...  stretching
# 840  [Extend both hands straight above your head, p...  stretching
# 844  [To begin, step onto the treadmill and select ...      cardio
# 864  [Lie on your back with your arms extended out ...  stretching
# 865  [This is a three-part stretch. Begin by lungin...  stretching
#
#                                                 images  \
# 1       [90_90_Hamstring/0.jpg, 90_90_Hamstring/1.jpg]
# 5         [Adductor_Groin/0.jpg, Adductor_Groin/1.jpg]
# 8    [All_Fours_Quad_Stretch/0.jpg, All_Fours_Quad_...
# 21   [Ankle_On_The_Knee/0.jpg, Ankle_On_The_Knee/1....
# 22   [Anterior_Tibialis-SMR/0.jpg, Anterior_Tibiali...
# ..                                                 ...
# 836  [Upper_Back_Stretch/0.jpg, Upper_Back_Stretch/...
# 840       [Upward_Stretch/0.jpg, Upward_Stretch/1.jpg]
# 844  [Walking_Treadmill/0.jpg, Walking_Treadmill/1....
# 864                 [Windmills/0.jpg, Windmills/1.jpg]
# 865  [Worlds_Greatest_Stretch/0.jpg, Worlds_Greates...
#
#                           id
# 1            90_90_Hamstring
# 5             Adductor_Groin
# 8     All_Fours_Quad_Stretch
# 21         Ankle_On_The_Knee
# 22     Anterior_Tibialis-SMR
# ..                       ...
# 836       Upper_Back_Stretch
# 840           Upward_Stretch
# 844        Walking_Treadmill
# 864                Windmills
# 865  Worlds_Greatest_Stretch
#
# [87 rows x 11 columns]

# %%
df.loc[df['mechanic'].isnull() & (df['category'] == 'stretching')]
# Out:
#                          name   force         level mechanic  equipment  \
# 1             90/90 Hamstring    push      beginner     None  body only
# 5              Adductor/Groin  static  intermediate     None       None
# 8      All Fours Quad Stretch  static  intermediate     None  body only
# 21          Ankle On The Knee  static      beginner     None       None
# 22      Anterior Tibialis-SMR  static  intermediate     None      other
# ..                        ...     ...           ...      ...        ...
# 835       Upper Back-Leg Grab  static      beginner     None       None
# 836        Upper Back Stretch  static      beginner     None       None
# 840            Upward Stretch  static      beginner     None       None
# 864                 Windmills    pull  intermediate     None       None
# 865  World's Greatest Stretch  static  intermediate     None       None
#
#     primaryMuscles                  secondaryMuscles  \
# 1     [hamstrings]                          [calves]
# 5      [adductors]                                []
# 8     [quadriceps]                      [quadriceps]
# 21        [glutes]                                []
# 22        [calves]                                []
# ..             ...                               ...
# 835   [hamstrings]         [lower back, middle back]
# 836  [middle back]                     [middle back]
# 840    [shoulders]                     [chest, lats]
# 864    [abductors]  [glutes, hamstrings, lower back]
# 865   [hamstrings]      [calves, glutes, quadriceps]
#
#                                           instructions    category  \
# 1    [Lie on your back, with one leg extended strai...  stretching
# 5    [Lie on your back with your feet raised toward...  stretching
# 8    [Start off on your hands and knees, then lift ...  stretching
# 21   [From a lying position, bend your knees and ke...  stretching
# 22   [Begin seated on the ground with your legs ben...  stretching
# ..                                                 ...         ...
# 835  [While seated, bend forward to hug your thighs...  stretching
# 836  [Clasp fingers together with your thumbs point...  stretching
# 840  [Extend both hands straight above your head, p...  stretching
# 864  [Lie on your back with your arms extended out ...  stretching
# 865  [This is a three-part stretch. Begin by lungin...  stretching
#
#                                                 images  \
# 1       [90_90_Hamstring/0.jpg, 90_90_Hamstring/1.jpg]
# 5         [Adductor_Groin/0.jpg, Adductor_Groin/1.jpg]
# 8    [All_Fours_Quad_Stretch/0.jpg, All_Fours_Quad_...
# 21   [Ankle_On_The_Knee/0.jpg, Ankle_On_The_Knee/1....
# 22   [Anterior_Tibialis-SMR/0.jpg, Anterior_Tibiali...
# ..                                                 ...
# 835  [Upper_Back-Leg_Grab/0.jpg, Upper_Back-Leg_Gra...
# 836  [Upper_Back_Stretch/0.jpg, Upper_Back_Stretch/...
# 840       [Upward_Stretch/0.jpg, Upward_Stretch/1.jpg]
# 864                 [Windmills/0.jpg, Windmills/1.jpg]
# 865  [Worlds_Greatest_Stretch/0.jpg, Worlds_Greates...
#
#                           id
# 1            90_90_Hamstring
# 5             Adductor_Groin
# 8     All_Fours_Quad_Stretch
# 21         Ankle_On_The_Knee
# 22     Anterior_Tibialis-SMR
# ..                       ...
# 835      Upper_Back-Leg_Grab
# 836       Upper_Back_Stretch
# 840           Upward_Stretch
# 864                Windmills
# 865  Worlds_Greatest_Stretch
#
# [67 rows x 11 columns]

# %%
df['category'].value_counts()
# Out:
# category
# strength                 581
# stretching               123
# plyometrics               61
# powerlifting              38
# olympic weightlifting     35
# strongman                 21
# cardio                    14
# Name: count, dtype: int64

# %%
df = df[~df['category'].isin(['stretching', 'plyometrics'])]

# %%
df.columns
# Out:
# Index(['name', 'force', 'level', 'mechanic', 'equipment', 'primaryMuscles',
#        'secondaryMuscles', 'instructions', 'category', 'images', 'id'],
#       dtype='object')

# %%
df.drop(columns=['instructions', 'images'], inplace=True)

# %%
df = df.loc[df['category']=='strength']

# %%
df.loc[df['level'] == 'expert']
# Out:
#                                    name force   level   mechanic    equipment  \
# 19             Alternating Renegade Row  pull  expert   compound  kettlebells
# 42        Barbell Ab Rollout - On Knees  pull  expert   compound      barbell
# 64             Barbell Squat To A Bench  push  expert   compound      barbell
# 86                           Bent Press  pull  expert   compound  kettlebells
# 103               Box Squat with Chains  push  expert   compound      barbell
# 214            Double Kettlebell Snatch  pull  expert   compound  kettlebells
# 284                 Front Barbell Squat  push  expert   compound      barbell
# 285      Front Barbell Squat To A Bench  push  expert   compound      barbell
# 312                  Handstand Push-Ups  push  expert   compound    body only
# 318                   Hanging Leg Raise  pull  expert  isolation    body only
# 319                        Hanging Pike  pull  expert   compound    body only
# 378             Kettlebell Pistol Squat  push  expert   compound  kettlebells
# 465                     Mixed Grip Chin  pull  expert   compound        other
# 494           One-Arm Kettlebell Snatch  pull  expert   compound  kettlebells
# 496     One-Arm Kettlebell Split Snatch  pull  expert   compound  kettlebells
# 501  One-Arm Overhead Kettlebell Squats  push  expert   compound  kettlebells
# 502               One-Arm Side Deadlift  pull  expert   compound      barbell
# 506                     One Arm Chin-Up  pull  expert   compound        other
# 516               One Leg Barbell Squat  push  expert   compound      barbell
# 517          Open Palm Kettlebell Clean  pull  expert   compound  kettlebells
# 543             Plyo Kettlebell Pushups  push  expert   compound  kettlebells
# 555                        Press Sit-Up  push  expert   compound      barbell
# 723                        Speed Squats  push  expert   compound      barbell
# 734                          Squat Jerk  push  expert   compound      barbell
# 851                Weighted Sissy Squat  push  expert   compound      barbell
# 870                      Zercher Squats  push  expert   compound      barbell
#
#     primaryMuscles                                   secondaryMuscles  \
# 19   [middle back]         [abdominals, biceps, chest, lats, triceps]
# 42    [abdominals]                            [lower back, shoulders]
# 64    [quadriceps]           [calves, glutes, hamstrings, lower back]
# 86    [abdominals]  [glutes, hamstrings, lower back, quadriceps, s...
# 103   [quadriceps]  [abductors, adductors, calves, glutes, hamstri...
# 214    [shoulders]                   [glutes, hamstrings, quadriceps]
# 284   [quadriceps]                       [calves, glutes, hamstrings]
# 285   [quadriceps]                       [calves, glutes, hamstrings]
# 312    [shoulders]                                          [triceps]
# 318   [abdominals]                                                 []
# 319   [abdominals]                                                 []
# 378   [quadriceps]            [calves, glutes, hamstrings, shoulders]
# 465  [middle back]                                     [biceps, lats]
# 494    [shoulders]  [calves, glutes, hamstrings, lower back, traps...
# 496    [shoulders]                           [hamstrings, quadriceps]
# 501   [quadriceps]            [calves, glutes, hamstrings, shoulders]
# 502   [quadriceps]  [abdominals, calves, glutes, hamstrings, lower...
# 506  [middle back]                           [biceps, forearms, lats]
# 516   [quadriceps]                       [calves, glutes, hamstrings]
# 517   [hamstrings]        [glutes, lower back, quadriceps, shoulders]
# 543        [chest]                               [shoulders, triceps]
# 555   [abdominals]                        [chest, shoulders, triceps]
# 723   [quadriceps]           [calves, glutes, hamstrings, lower back]
# 734   [quadriceps]   [calves, glutes, hamstrings, shoulders, triceps]
# 851   [quadriceps]                       [calves, glutes, hamstrings]
# 870   [quadriceps]                       [calves, glutes, hamstrings]
#
#      category                                  id
# 19   strength            Alternating_Renegade_Row
# 42   strength       Barbell_Ab_Rollout_-_On_Knees
# 64   strength            Barbell_Squat_To_A_Bench
# 86   strength                          Bent_Press
# 103  strength               Box_Squat_with_Chains
# 214  strength            Double_Kettlebell_Snatch
# 284  strength                 Front_Barbell_Squat
# 285  strength      Front_Barbell_Squat_To_A_Bench
# 312  strength                  Handstand_Push-Ups
# 318  strength                   Hanging_Leg_Raise
# 319  strength                        Hanging_Pike
# 378  strength             Kettlebell_Pistol_Squat
# 465  strength                     Mixed_Grip_Chin
# 494  strength           One-Arm_Kettlebell_Snatch
# 496  strength     One-Arm_Kettlebell_Split_Snatch
# 501  strength  One-Arm_Overhead_Kettlebell_Squats
# 502  strength               One-Arm_Side_Deadlift
# 506  strength                     One_Arm_Chin-Up
# 516  strength               One_Leg_Barbell_Squat
# 517  strength          Open_Palm_Kettlebell_Clean
# 543  strength             Plyo_Kettlebell_Pushups
# 555  strength                        Press_Sit-Up
# 723  strength                        Speed_Squats
# 734  strength                          Squat_Jerk
# 851  strength                Weighted_Sissy_Squat
# 870  strength                      Zercher_Squats

# %%
df['primaryMuscles'].value_counts()
# Out:
# primaryMuscles
# [shoulders]      104
# [abdominals]      81
# [chest]           67
# [quadriceps]      60
# [triceps]         58
# [biceps]          50
# [middle back]     30
# [lats]            29
# [hamstrings]      28
# [forearms]        21
# [calves]          15
# [traps]           13
# [glutes]          11
# [neck]             5
# [lower back]       5
# [adductors]        2
# [abductors]        2
# Name: count, dtype: int64

# %%
legs = ['quadriceps', 'hamstrings', 'glutes', 'calves', 'adductors', 'abductors']
legs_list = [[x] for x in legs]
df['force'] = np.where(df['primaryMuscles'].isin(legs_list), 'legs', df['force'])

# %%
df['force'].value_counts()
# Out:
# force
# pull      259
# push      192
# legs      118
# static      6
# Name: count, dtype: int64

# %%
df.loc[df['force'].isnull()]
# Out:
#                             name force     level   mechanic  equipment  \
# 35         Band Assisted Pull-Up  None  beginner   compound      other
# 345    Incline Inner Biceps Curl  None  beginner  isolation   dumbbell
# 354  Internal Rotation with Band  None  beginner  isolation      bands
# 560                 Push-Up Wide  None  beginner   compound  body only
# 682        Single Dumbbell Raise  None  beginner  isolation   dumbbell
# 702  Smith Machine Decline Press  None  beginner   compound    machine
#
#     primaryMuscles                     secondaryMuscles  category  \
# 35          [lats]  [abdominals, forearms, middle back]  strength
# 345       [biceps]                                   []  strength
# 354    [shoulders]                                   []  strength
# 560        [chest]     [abdominals, shoulders, triceps]  strength
# 682    [shoulders]                    [forearms, traps]  strength
# 702        [chest]                 [shoulders, triceps]  strength
#
#                               id
# 35         Band_Assisted_Pull-Up
# 345    Incline_Inner_Biceps_Curl
# 354  Internal_Rotation_with_Band
# 560                 Push-Up_Wide
# 682        Single_Dumbbell_Raise
# 702  Smith_Machine_Decline_Press

# %%
df['mechanic'].value_counts()
# Out:
# mechanic
# compound     327
# isolation    249
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# name                0
# force               0
# level               0
# mechanic            4
# equipment           6
# primaryMuscles      0
# secondaryMuscles    0
# category            0
# id                  0
# dtype: int64

# %%
df = pd.read_csv('context_exercises.csv')

# %%
df.isnull().sum()
# Out:
# name                0
# force               0
# level               0
# mechanic            0
# equipment           0
# primaryMuscles      0
# secondaryMuscles    0
# category            0
# id                  0
# dtype: int64

# %%
df = df[df['mechanic'].notna()]

# %%
null_equipment = ['body only','barbell','body only','barbell','body only','body only']

# %%
df.loc[df['equipment'].isnull(), 'equipment'] = null_equipment

# %%
df.to_csv("context_exercises.csv", index=False)
